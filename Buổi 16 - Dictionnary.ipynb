# %% [markdown]
# # Dictionnary
#
# Dictionnary là một dạng list đặc biệt, nó khác list ở chỗ không lưu trữ các giá trị theo chỉ số vị trí, thay vào đó Dictionary sẽ lưu trữ các giá trị theo key
#
# ##### Tài liệu tham khảo: https://www.w3schools.com/python/python_dictionaries.asp
#
# ### Khai báo một dictionary
#
# Cú pháp:
#
# `<tên dictionary> = {}`
#
# ### Dictionary được khai báo bằng hai dấu hoặc nhọn
#
# Đây là một dictionary rỗng
#
# <b>Ví dụ 1:</b>
#
# `a = {}`
#
# a là một dictionary rỗng
#
# <b>Ví dụ 2:</b>
#
# `a = {"tên": "Nguyễn Tâm Điền", "tuổi": 13, "giới tính": "Nam"}`
#
# b là một dictionary có 3 key, mõi key đều có một giá trị riêng biệt
#
# Key có thể mang kiểu dữ liệu là chuỗi hoặc số
#
# ##### Mỗi một key đều phải có giá trị của riêng nó, không thể khai báo key không có giá trị
#
# <b>Hãy khai báo một dictionary có 3 phần tử</b>

# %%
dict_a = {"name": "Nguyễn Tâm Điền", "age": 13, "gender": "nam"}

print(dict_a)
# Out:
# {'name': 'Nguyễn Tâm Điền', 'age': 13, 'gender': 'nam'}

# %%
dict_a = {}

print(dict_a)
# Out:
# {}

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "name": "Đặng Quang Dũng"
}

print(dict_a)
# Out:
# {'name': 'Đặng Quang Dũng', 'age': 13, 'gender': 'nam'}

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "tên": "Nguyễn Tâm Điền"
}

print(dict_a)
# Out:
# {'name': 'Nguyễn Tâm Điền', 'age': 13, 'gender': 'nam', 'tên': 'Nguyễn Tâm Điền'}

# %% [markdown]
# ### Thêm key vào dictionary
#
# Cú pháp:
#
# `<tên dictionary>[<key>] = <giá trị>`
#
# <b>Ví dụ 1:</b>
#
# ```
# a = {}
# a["tên"] = "NTD"
# ```
#
# a là một dictionary có một phần tử, phần tử đó có key là "tên" và giá trị của key đó là "NTD"
#
# ##### Lưu ý, nếu trong trường hợp đã tồn tại key trong dictionary, dùng lệnh trên sẽ thay đổi giá trị key đó (không phải thêm key khác vào)
#
# <b>Ví dụ 2:</b>
#
# ```
# a = {}
# a["tên"] = "NTD"
# a["tên"] = "Nguyễn Tâm Điền"
# ```
#
# a vẫn là một dictionary có một phần tử, phần tử đó có key là "tên" và giá trị của key đó là "Nguyễn Tâm Điền"
#
# <b>Hãy khai báo một dictionary không có phần tử nào, sau đó thêm một phần tử vào dictionary đó</b>

# %%
dict_a = {}

dict_a["abc"] = "xin chào"
print(dict_a)
# Out:
# {'abc': 'xin chào'}

# %%
dict_a = {"abc": "hi"}

dict_a["abc"] = "xin chào"
print(dict_a)
# Out:
# {'abc': 'xin chào'}

# %%
list_a = [1, 2, 3]

if 2 in list_a:
    print("hi")
# Out:
# hi

# %%
dict_a = {"abc": "hi"}

if "abc" in dict_a:
    print("hello")
# Out:
# hello

# %% [markdown]
# ### Truy xuất phần tử trong dictionary
#
# Cú pháp:
#
# `<tên dictionary>[<key>]`
#
# <b>Ví dụ:</b>
#
# ```
# a = {"tên": "Nguyễn Tâm Điền", "tuổi": 13, "giới tính": "Nam"}
# print(a["tên"])
# ```
#
# Màn hình sẽ in: Nguyễn Tâm Điền
#
# <b>Hãy khai báo một dictionary rồi in ra màn hình một phần tử bất kỳ trong dictionary đó</b>

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "tên": "Nguyễn Tâm Điền"
}

gia_tri = dict_a["gender"]
print(gia_tri)
# Out:
# nam

# %%
### Danh sách sinh viên
### MSSV | Họ và Tên | Địa chỉ
### 0001 | Đặng Quang Dung | Hà Tây
### 0002 | Gia Hiếu | Sài Gòn

## JSON ~~> Javascript Object Notation

danh_sach_sinh_vien = [
    {"mssv": "0001", "name": "Đặng Quang Dũng", "address": "Hà Tây"},
    {"mssv": "0002", "name": "Gia Hiếu", "address": "Sài Gòn"},
]

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "tên": "Nguyễn Tâm Điền"
}

dict_b = dict_a.copy()

dict_a["address"] = "Sài Gòn"

print(dict_a)
print(dict_b)
# Out:
# {'name': 'Nguyễn Tâm Điền', 'age': 13, 'gender': 'nam', 'tên': 'Nguyễn Tâm Điền', 'address': 'Sài Gòn'}
# {'name': 'Nguyễn Tâm Điền', 'age': 13, 'gender': 'nam', 'tên': 'Nguyễn Tâm Điền'}

# %% [markdown]
# ### Sao chép dictionary
#
# ##### Việc sao chép dictionary được thực hiện hệt như sao chép list, chúng ta cần phải sử dụng lệnh copy()

# %% [markdown]
# ### Duyệt dictionary bằng lệnh for
#
# Cú pháp:
#
# `for <tên biến> in <tên dictionary>:`
#
# Biến sẽ có giá trị là từng key trong dictionary
#
# <b>Ví dụ:</b>
#
# ```
# a = {"tên": "Nguyễn Tâm Điền", "tuổi": 13, "giới tính": "Nam"}
# for i in a:
#     print(i)
# ```
#
# Màn hình sẽ in ra:
#
# tên
#
# tuổi
#
# giới tính
#
# <b>Hãy khai báo một dictionary rồi in ra màn hình toàn bộ giá trị trong dictionary đó</b>

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "tên": "Nguyễn Tâm Điền"
}

print(len(dict_a))
# Out:
# 4

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "tên": "Nguyễn Tâm Điền"
}

gia_tri = dict_a[0]
print(gia_tri)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 8
#       1 dict_a = {
#       2     "name": "Nguyễn Tâm Điền",
#       3     "age": 13,
#       4     "gender": "nam",
#       5     "tên": "Nguyễn Tâm Điền"
#       6 }
# ----> 8 gia_tri = dict_a[0]
#       9 print(gia_tri)
#
# KeyError: 0

# %%
dict_a = {
    "name": "Nguyễn Tâm Điền",
    "age": 13,
    "gender": "nam",
    "tên": "Nguyễn Tâm Điền"
}

for key in dict_a:
    print(key, dict_a[key])
# Out:
# name Nguyễn Tâm Điền
# age 13
# gender nam
# tên Nguyễn Tâm Điền

# %% [markdown]
# ### Bài tập

# %% [markdown]
# Viết chương trình đếm số lần xuất hiện của một từ trong một văn bản nhất định

# %%
van_ban = """
Không có kính không phải vì xe không có kính
Bom giật, bom rung kính vỡ đi rồi
Ung dung buồng lái ta ngồi,
Nhìn đất, nhìn trời, nhìn thẳng.

Nhìn thấy gió vào xoa mắt đắng
Nhìn thấy con đường chạy thẳng vào tim
Thấy sao trời và đột ngột cánh chim
Như sa, như ùa vào buồng lái

Không có kính, ừ thì có bụi,
Bụi phun tóc trắng như người già
Chưa cần rửa, phì phèo châm điếu thuốc
Nhìn nhau mặt lấm cười ha ha.

Không có kính, ừ thì ướt áo
Mưa tuôn, mưa xối như ngoài trời
Chưa cần thay, lái trăm cây số nữa
Mưa ngừng, gió lùa khô mau thôi.

Những chiếc xe từ trong bom rơi
Đã về đây họp thành tiểu đội
Gặp bè bạn suốt dọc đường đi tới
Bắt tay qua cửa kính vỡ rồi.

Bếp Hoàng Cầm ta dựng giữa trời
Chung bát đũa nghĩa là gia đình đấy
Võng mắc chông chênh đường xe chạy
Lại đi, lại đi trời xanh thêm.

Không có kính, rồi xe không có đèn,
Không có mui xe, thùng xe có xước,
Xe vẫn chạy vì miền Nam phía trước:
Chỉ cần trong xe có một trái tim.
"""

# tạo ra 1 dictionary có định dạng:
# {"từ": số lượng từ xuất hiện}
# {"không": 3, "có": 7}
for ky_tu in van_ban:
    if ky_tu != " " and ky_tu != "\n" and not ky_tu.isalpha():
        van_ban = van_ban.replace(ky_tu, "")

### tách từ
list_tu = van_ban.lower().split()
print(list_tu)
dict_tu = {}
for tu in list_tu:
    if tu not in dict_tu:
        dict_tu[tu] = 0
    dict_tu[tu] += 1

print(dict_tu)
### tìm từ xuất hiện nhiều nhất

gia_tri_lon_nhat = 0
key_lon_nhat = ""

for tu in dict_tu:
    if dict_tu[tu] > gia_tri_lon_nhat :
        gia_tri_lon_nhat = dict_tu[tu]
        key_lon_nhat = tu

print("Từ xuất hiện nhiều nhất là:", key_lon_nhat, "| Với số lần là:", gia_tri_lon_nhat)
# Out:
# ['không', 'có', 'kính', 'không', 'phải', 'vì', 'xe', 'không', 'có', 'kính', 'bom', 'giật', 'bom', 'rung', 'kính', 'vỡ', 'đi', 'rồi', 'ung', 'dung', 'buồng', 'lái', 'ta', 'ngồi', 'nhìn', 'đất', 'nhìn', 'trời', 'nhìn', 'thẳng', 'nhìn', 'thấy', 'gió', 'vào', 'xoa', 'mắt', 'đắng', 'nhìn', 'thấy', 'con', 'đường', 'chạy', 'thẳng', 'vào', 'tim', 'thấy', 'sao', 'trời', 'và', 'đột', 'ngột', 'cánh', 'chim', 'như', 'sa', 'như', 'ùa', 'vào', 'buồng', 'lái', 'không', 'có', 'kính', 'ừ', 'thì', 'có', 'bụi', 'bụi', 'phun', 'tóc', 'trắng', 'như', 'người', 'già', 'chưa', 'cần', 'rửa', 'phì', 'phèo', 'châm', 'điếu', 'thuốc', 'nhìn', 'nhau', 'mặt', 'lấm', 'cười', 'ha', 'ha', 'không', 'có', 'kính', 'ừ', 'thì', 'ướt', 'áo', 'mưa', 'tuôn', 'mưa', 'xối', 'như', 'ngoài', 'trời', 'chưa', 'cần', 'thay', 'lái', 'trăm', 'cây', 'số', 'nữa', 'mưa', 'ngừng', 'gió', 'lùa', 'khô', 'mau', 'thôi', 'những', 'chiếc', 'xe', 'từ', 'trong', 'bom', 'rơi', 'đã', 'về', 'đây', 'họp', 'thành', 'tiểu', 'đội', 'gặp', 'bè', 'bạn', 'suốt', 'dọc', 'đường', 'đi', 'tới', 'bắt', 'tay', 'qua', 'cửa', 'kính', 'vỡ', 'rồi', 'bếp', 'hoàng', 'cầm', 'ta', 'dựng', 'giữa', 'trời', 'chung', 'bát', 'đũa', 'nghĩa', 'là', 'gia', 'đình', 'đấy', 'võng', 'mắc', 'chông', 'chênh', 'đường', 'xe', 'chạy', 'lại', 'đi', 'lại', 'đi', 'trời', 'xanh', 'thêm', 'không', 'có', 'kính', 'rồi', 'xe', 'không', 'có', 'đèn', 'không', 'có', 'mui', 'xe', 'thùng', 'xe', 'có', 'xước', 'xe', 'vẫn', 'chạy', 'vì', 'miền', 'nam', 'phía', 'trước', 'chỉ', 'cần', 'trong', 'xe', 'có', 'một', 'trái', 'tim']
# {'không': 8, 'có': 10, 'kính': 7, 'phải': 1, 'vì': 2, 'xe': 8, 'bom': 3, 'giật': 1, 'rung': 1, 'vỡ': 2, 'đi': 4, 'rồi': 3, 'ung': 1, 'dung': 1, 'buồng': 2, 'lái': 3, 'ta': 2, 'ngồi': 1, 'nhìn': 6, 'đất': 1, 'trời': 5, 'thẳng': 2, 'thấy': 3, 'gió': 2, 'vào': 3, 'xoa': 1, 'mắt': 1, 'đắng': 1, 'con': 1, 'đường': 3, 'chạy': 3, 'tim': 2, 'sao': 1, 'và': 1, 'đột': 1, 'ngột': 1, 'cánh': 1, 'chim': 1, 'như': 4, 'sa': 1, 'ùa': 1, 'ừ': 2, 'thì': 2, 'bụi': 2, 'phun': 1, 'tóc': 1, 'trắng': 1, 'người': 1, 'già': 1, 'chưa': 2, 'cần': 3, 'rửa': 1, 'phì': 1, 'phèo': 1, 'châm': 1, 'điếu': 1, 'thuốc': 1, 'nhau': 1, 'mặt': 1, 'lấm': 1, 'cười': 1, 'ha': 2, 'ướt': 1, 'áo': 1, 'mưa': 3, 'tuôn': 1, 'xối': 1, 'ngoài': 1, 'thay': 1, 'trăm': 1, 'cây': 1, 'số': 1, 'nữa': 1, 'ngừng': 1, 'lùa': 1, 'khô': 1, 'mau': 1, 'thôi': 1, 'những': 1, 'chiếc': 1, 'từ': 1, 'trong': 2, 'rơi': 1, 'đã': 1, 'về': 1, 'đây': 1, 'họp': 1, 'thành': 1, 'tiểu': 1, 'đội': 1, 'gặp': 1, 'bè': 1, 'bạn': 1, 'suốt': 1, 'dọc': 1, 'tới': 1, 'bắt': 1, 'tay': 1, 'qua': 1, 'cửa': 1, 'bếp': 1, 'hoàng': 1, 'cầm': 1, 'dựng': 1, 'giữa': 1, 'chung': 1, 'bát': 1, 'đũa': 1, 'nghĩa': 1, 'là': 1, 'gia': 1, 'đình': 1, 'đấy': 1, 'võng': 1, 'mắc': 1, 'chông': 1, 'chênh': 1, 'lại': 2, 'xanh': 1, 'thêm': 1, 'đèn': 1, 'mui': 1, 'thùng': 1, 'xước': 1, 'vẫn': 1, 'miền': 1, 'nam': 1, 'phía': 1, 'trước': 1, 'chỉ': 1, 'một': 1, 'trái': 1}
# Từ xuất hiện nhiều nhất là: có | Với số lần là: 10

# %% [markdown]
# Viết chương trình cho phép người dùng quản lý sản phẩm, gồm các chức năng sau:
#
# - Hiển thị danh sách sản phẩm
# - Thêm sản phẩm mới vào danh sách
# - Sửa tên của sản phẩm trong danh sách
# - Xoá một sản phẩm khỏi danh sách
