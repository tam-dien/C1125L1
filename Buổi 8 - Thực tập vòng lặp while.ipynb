# %% [markdown]
# # Thực tập vòng lặp While
#
# ### Bài 1
#
# Nhập vào số a, sử dụng lệnh while (không sử dụng break và for) để xác định xem số đó có phải là số nguyên tố hay không

# %%
a = int(input("Nhập a:"))
check = True
for i in range(2,int(a**0.5)):
    if a % i == 0: # có ước
        check = False
        break
    
if check:
    print(a, "là số nguyên tố")
else:
    print(a, "không là số nguyên tố")
# Out:
# 16 không là số nguyên tố

# %% [markdown]
# ### Bài 2
#
# Hãy sử dụng lệnh while lập trình cho bài đoán số ở buổi thứ 9

# %% [markdown]
# ### Bài 3
#
# Nhập vào số a, hãy đếm a có bao nhiêu chữ số chẵn, bao nhiêu cữ số lẻ
#
# #### Cách 1 (dùng chuỗi):

# %% [markdown]
# #### Cách 2 (không dùng chuỗi):

# %%
a = int(input("Nhập số nguyên dương a: "))

x = a 
chan = 0
le = 0

while x > 0:
    chu_so = x % 10  
    
    if chu_so % 2 == 0:
        chan += 1 
    else:
        le += 1   
        
    x //= 10  

print("Số",a ,"có", chan ,"chữ số chẵn và", le ,"chữ số lẻ.")
# Out:
# Số 5983 có 1 chữ số chẵn và 3 chữ số lẻ.

# %% [markdown]
# ### Bài 4
#
# Nhập vào số a, hãy tính tổng các chữ số nguyên tố của a

# %%
a = int(input("Nhập số nguyên dương a: "))
a_goc = a
tong = 0

while a > 0:
    x = a % 10   

    if x == 2 or x == 3 or x == 5 or x == 7:
        tong += x

    a //= 10     

print("Tổng các số nguyên tố của", a_goc,"là:", tong)
# Out:
# Tổng các số nguyên tố của 7602 là: 9

# %% [markdown]
# ### Bài 5
#
# Số armstrong là số có tổng của các chữ số mũ số lượng chữ số bằng chính nó
#
# Ví dụ
#
# Số 371 là một số armstrong vì:
#
# 371 = 3^3 + 7^3 + 1^3 (3 là số lượng chữ số của 371)
#
# Số 1634 là một số armstrong vì:
#
# 1634 = 1^4 + 6^4 + 3^4 + 4^4 (4 là số lượng chữ số của 1634)
#
# Nhập vào số a, kiểm tra xem a có phải là số armstrong không

# %%
a = int(input("Nhập vào số a: "))
a_goc = a
so_luong_chu_so = len(str(a))

tong = 0 
while a > 0:
    chu_so = a % 10
    a //= 10
    tong += chu_so**so_luong_chu_so
    
if tong == a_goc:
    print(a_goc, "là số armstrong")
else:
    print(a_goc, "không phải là số armstrong")
# Out:
# 1634 là số armstrong

# %% [markdown]
# ### Bài 6
#
# Dãy số fibonacci là dãy số được định nghĩa như sau: 1, 1, 2, 3, 5, 8, 13,... với số kế tiếp sẽ bằng tổng hai số trước đó
#
# Nhập vào A, hãy tìm số trong dãy số fibonacci lớn nhất nhưng không vượt quá A

# %%
A = int(input("Nhập A:"))

a = 1
b = 1

while b <= A: # dừng lại khi b > A
    a, b = b, a + b

print("Fibonacci lớn nhất không vượt quá",A,"là:",a)
# Out:
# Fibonacci lớn nhất không vượt quá 9 là: 8

# %% [markdown]
# ### Bài 7
#
# Nhập vào A, tìm n nhỏ nhất sao cho
#
# 1 + 1/2 + 1/3 + 1/4 + ... + 1/n > A

# %%
a = float(input("Nhập vào số a:"))
print("Số a đã nhập là:",a)

n = 1
tong = 1

while tong <= a:
    n += 1
    tong += 1/n
    
print("Tổng của dãy số là:",tong)
print("Sô n nhỏ nhất là:",n)
# Out:
# Số a đã nhập là: 1.4
# Tổng của dãy số là: 1.5
# Sô n nhỏ nhất là: 2

# %% [markdown]
# ### Bài 8
#
# Nhập vào a và b là số nguyên dương (b có một chữ số, nhập sai yêu cầu nhập lại), hãy tìm vị trí đầu tiên (bắt đầu từ bên trái) của b trong a, nếu không tìm thấy thì in kết quả là 0 (ví trí đầu bắt đầu từ 1)
#
# <b>Ví dụ:</b>
#
# <b>Nhập:</b>
# - a = 125785
# - b = 5
#
# <b>Kết quả:</b> 3 (do số 5 nằm ở vị trí 3)

# %%
a = input("Nhập vào số a:")
while True:
    b = int(input("Nhập vào số b 1 chữ số:"))
    if  0 <= b <= 9:
        break

print("Số a đã nhập là:",a)
print("Số b đã nhập là:",b)

so_luong_chu_so = len(a)
i = 0
while i < so_luong_chu_so:
    if a[i] == str(b):
        print("Số thứ tự của b ở a là :", i + 1)
        break
    i += 1

if i == so_luong_chu_so:
    print("Không tìm thấy vị trí b trong a")
# Out:
# Số a đã nhập là: 125785
# Số b đã nhập là: 5
# Số thứ tự của b ở a là : 3
